# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 3  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 4  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 3   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 4   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
# 1                 NaN        NaN                NaN              4
# 2                 NaN        NaN                NaN              5
# 3                 NaN        NaN                NaN              5
# 4                 NaN        NaN                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
# 2  https://www.amazon.com/product-reviews/B00QWO9...
# 3  https://www.amazon.com/product-reviews/B00QWO9...
# 4  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...
# 3  https://www.barcodable.com/upc/841710106442,ht...
# 4  https://www.barcodable.com/upc/841710106442,ht...
#
# [5 rows x 24 columns]

# %%
df.rename(columns = {'Unnamed: 0':'Id'}, inplace = True)

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 3  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 4  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 3   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 4   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
# 1                 NaN        NaN                NaN              4
# 2                 NaN        NaN                NaN              5
# 3                 NaN        NaN                NaN              5
# 4                 NaN        NaN                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
# 2  https://www.amazon.com/product-reviews/B00QWO9...
# 3  https://www.amazon.com/product-reviews/B00QWO9...
# 4  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...
# 3  https://www.barcodable.com/upc/841710106442,ht...
# 4  https://www.barcodable.com/upc/841710106442,ht...
#
# [5 rows x 24 columns]

# %%
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['reviews.text']
    myid = row['id']
    res[myid] = sia.polarity_scores(str(text))
# Out:
#   0%|          | 0/28332 [00:00<?, ?it/s]

# %%
res
# Out:
# {'AVpgNzjwLJeJML43Kpxn': {'neg': 0.183,
#   'neu': 0.674,
#   'pos': 0.142,
#   'compound': -0.5463},
#  'AVpe7nGV1cnluZ0-aG2o': {'neg': 0.045,
#   'neu': 0.871,
#   'pos': 0.084,
#   'compound': 0.8639},
#  'AVpfl8cLLJeJML43AE3S': {'neg': 0.0,
#   'neu': 0.862,
#   'pos': 0.138,
#   'compound': 0.5859},
#  'AWK8z0pOIwln0LfXlSxH': {'neg': 0.043,
#   'neu': 0.824,
#   'pos': 0.133,
#   'compound': 0.6908},
#  'AWYAV-i9Iwln0LfXqrUq': {'neg': 0.021,
#   'neu': 0.749,
#   'pos': 0.23,
#   'compound': 0.9525},
#  'AWFFfd9KIwln0LfXiOe0': {'neg': 0.0,
#   'neu': 0.442,
#   'pos': 0.558,
#   'compound': 0.9708},
#  'AVpe7xlELJeJML43ypLz': {'neg': 0.057,
#   'neu': 0.852,
#   'pos': 0.092,
#   'compound': 0.3802},
#  'AVphC37X1cnluZ0-9mbp': {'neg': 0.183,
#   'neu': 0.785,
#   'pos': 0.032,
#   'compound': -0.8749},
#  'AVpf68A5ilAPnD_xkjSq': {'neg': 0.062,
#   'neu': 0.889,
#   'pos': 0.049,
#   'compound': -0.1045},
#  'AVpe6nyKLJeJML43yOe2': {'neg': 0.076,
#   'neu': 0.756,
#   'pos': 0.167,
#   'compound': 0.9804},
#  'AVpflnS7ilAPnD_xehxE': {'neg': 0.107,
#   'neu': 0.725,
#   'pos': 0.168,
#   'compound': 0.197},
#  'AVpfzuRNilAPnD_xipqB': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'AVpfhcniLJeJML43-t4G': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'AWdDioCIHh53nbDRScLV': {'neg': 0.0,
#   'neu': 0.094,
#   'pos': 0.906,
#   'compound': 0.8655},
#  'AVpfIfGA1cnluZ0-emyp': {'neg': 0.171,
#   'neu': 0.829,
#   'pos': 0.0,
#   'compound': -0.5423},
#  'AVpgyLH7ilAPnD_xxQ07': {'neg': 0.034,
#   'neu': 0.806,
#   'pos': 0.16,
#   'compound': 0.9877},
#  'AV2ElNnuvKc47QAVouhY': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'AVpfv-vJilAPnD_xhk-O': {'neg': 0.065,
#   'neu': 0.866,
#   'pos': 0.07,
#   'compound': 0.696},
#  'AVzvXXXN-jtxr-f3z35Q': {'neg': 0.0,
#   'neu': 0.866,
#   'pos': 0.134,
#   'compound': 0.7609},
#  'AVpfpK8KLJeJML43BCuD': {'neg': 0.0,
#   'neu': 0.814,
#   'pos': 0.186,
#   'compound': 0.6249},
#  'AVqVGZNvQMlgsOJE6eUY': {'neg': 0.0,
#   'neu': 0.693,
#   'pos': 0.307,
#   'compound': 0.8987},
#  'AVpgjNRkilAPnD_xuALS': {'neg': 0.019,
#   'neu': 0.836,
#   'pos': 0.145,
#   'compound': 0.802},
#  'AVzvV7FHglJLPUi8GzhD': {'neg': 0.0,
#   'neu': 0.6,
#   'pos': 0.4,
#   'compound': 0.9186},
#  'AVpe7JuRilAPnD_xQ_M6': {'neg': 0.034,
#   'neu': 0.912,
#   'pos': 0.054,
#   'compound': 0.4846},
#  'AVpgEm3DLJeJML43Id7b': {'neg': 0.0,
#   'neu': 0.256,
#   'pos': 0.744,
#   'compound': 0.4404},
#  'AWMjXUGdHh53nbDRJ9LA': {'neg': 0.023,
#   'neu': 0.797,
#   'pos': 0.179,
#   'compound': 0.8555},
#  'AVphPmHuilAPnD_x3E5h': {'neg': 0.044,
#   'neu': 0.653,
#   'pos': 0.303,
#   'compound': 0.9337},
#  'AVpiZQ8r1cnluZ0-M3MN': {'neg': 0.0,
#   'neu': 0.712,
#   'pos': 0.288,
#   'compound': 0.8521},
#  'AWdDlIX9Hh53nbDRSc-U': {'neg': 0.0,
#   'neu': 0.859,
#   'pos': 0.141,
#   'compound': 0.8957},
#  'AWMjN1SSIwln0LfXmWs7': {'neg': 0.0,
#   'neu': 0.579,
#   'pos': 0.421,
#   'compound': 0.8957},
#  'AVqVGWQDv8e3D1O-ldFr': {'neg': 0.063,
#   'neu': 0.622,
#   'pos': 0.315,
#   'compound': 0.9621},
#  'AVpfw2hvilAPnD_xh0rH': {'neg': 0.131,
#   'neu': 0.773,
#   'pos': 0.097,
#   'compound': -0.0387},
#  'AVqkIiKWnnc1JgDc3khH': {'neg': 0.0,
#   'neu': 0.694,
#   'pos': 0.306,
#   'compound': 0.8934},
#  'AVqkIh8WQMlgsOJE6fu-': {'neg': 0.0,
#   'neu': 0.694,
#   'pos': 0.306,
#   'compound': 0.8934},
#  'AVqVGZN9QMlgsOJE6eUZ': {'neg': 0.0,
#   'neu': 0.618,
#   'pos': 0.382,
#   'compound': 0.9626},
#  'AVpftoij1cnluZ0-p5n2': {'neg': 0.0,
#   'neu': 0.826,
#   'pos': 0.174,
#   'compound': 0.6114},
#  'AVzYlGnuGV-KLJ3abPUD': {'neg': 0.047,
#   'neu': 0.565,
#   'pos': 0.388,
#   'compound': 0.9059},
#  'AVpgdkC8ilAPnD_xsvyi': {'neg': 0.0,
#   'neu': 0.528,
#   'pos': 0.472,
#   'compound': 0.8381},
#  'AVqkIhkhv8e3D1O-lebZ': {'neg': 0.042,
#   'neu': 0.892,
#   'pos': 0.066,
#   'compound': 0.3626},
#  'AVqkIh9HQMlgsOJE6fu_': {'neg': 0.0,
#   'neu': 0.694,
#   'pos': 0.306,
#   'compound': 0.8934},
#  'AVqVGZO3nnc1JgDc3jGK': {'neg': 0.0,
#   'neu': 0.654,
#   'pos': 0.346,
#   'compound': 0.5719},
#  'AVpidLjVilAPnD_xEVpI': {'neg': 0.0,
#   'neu': 0.866,
#   'pos': 0.134,
#   'compound': 0.5848},
#  'AVzYlGj3vKc47QAVeZRH': {'neg': 0.0,
#   'neu': 0.817,
#   'pos': 0.183,
#   'compound': 0.6808},
#  'AVpe5Q3sLJeJML43xt5X': {'neg': 0.0,
#   'neu': 0.631,
#   'pos': 0.369,
#   'compound': 0.6249},
#  'AV-ETMhgYSSHbkXwpNb9': {'neg': 0.075,
#   'neu': 0.646,
#   'pos': 0.279,
#   'compound': 0.7902},
#  'AVpfTWGdLJeJML436ocu': {'neg': 0.0,
#   'neu': 0.954,
#   'pos': 0.046,
#   'compound': 0.2724},
#  'AVwjfXqqQMlgsOJE8qmm': {'neg': 0.0,
#   'neu': 0.649,
#   'pos': 0.351,
#   'compound': 0.8957},
#  'AVwjfXp4QMlgsOJE8qmk': {'neg': 0.0,
#   'neu': 0.54,
#   'pos': 0.46,
#   'compound': 0.902},
#  'AVzYlGkFvKc47QAVeZRI': {'neg': 0.173,
#   'neu': 0.699,
#   'pos': 0.128,
#   'compound': -0.541},
#  'AVzNj1Y0GV-KLJ3aarCo': {'neg': 0.062,
#   'neu': 0.808,
#   'pos': 0.13,
#   'compound': 0.8268},
#  'AVqkIdZiv8e3D1O-leaJ': {'neg': 0.0,
#   'neu': 0.528,
#   'pos': 0.472,
#   'compound': 0.8381},
#  'AVzoFq6UvKc47QAVe9NB': {'neg': 0.055,
#   'neu': 0.809,
#   'pos': 0.135,
#   'compound': 0.6899},
#  'AVpjEN4jLJeJML43rpUe': {'neg': 0.0,
#   'neu': 0.528,
#   'pos': 0.472,
#   'compound': 0.8381},
#  'AVqVGZQBQMlgsOJE6eUb': {'neg': 0.0,
#   'neu': 0.618,
#   'pos': 0.382,
#   'compound': 0.9626},
#  'AV-EVZITKZqtpbFMSoqc': {'neg': 0.0,
#   'neu': 0.581,
#   'pos': 0.419,
#   'compound': 0.6187},
#  'AVph0EeEilAPnD_x9myq': {'neg': 0.131,
#   'neu': 0.773,
#   'pos': 0.097,
#   'compound': -0.0387},
#  'AVqkIj9snnc1JgDc3khU': {'neg': 0.0,
#   'neu': 0.694,
#   'pos': 0.306,
#   'compound': 0.8934},
#  'AVqVGWLKnnc1JgDc3jF1': {'neg': 0.131,
#   'neu': 0.773,
#   'pos': 0.097,
#   'compound': -0.0387},
#  'AVqVGZSEQMlgsOJE6eUc': {'neg': 0.0,
#   'neu': 0.638,
#   'pos': 0.362,
#   'compound': 0.7783},
#  'AVpi6NtY1cnluZ0-RuRs': {'neg': 0.0,
#   'neu': 0.732,
#   'pos': 0.268,
#   'compound': 0.765},
#  'AVzvXXwEvKc47QAVfRhx': {'neg': 0.077,
#   'neu': 0.864,
#   'pos': 0.058,
#   'compound': -0.3676},
#  'AWP6zKOtIwln0LfXnf2p': {'neg': 0.0,
#   'neu': 0.654,
#   'pos': 0.346,
#   'compound': 0.9858},
#  'AVpiGyzGLJeJML43iUdJ': {'neg': 0.062,
#   'neu': 0.854,
#   'pos': 0.084,
#   'compound': 0.8299},
#  'AVpf2cQm1cnluZ0-sb5y': {'neg': 0.268,
#   'neu': 0.629,
#   'pos': 0.103,
#   'compound': -0.9555},
#  'AVqkIhxunnc1JgDc3kg_': {'neg': 0.063,
#   'neu': 0.622,
#   'pos': 0.315,
#   'compound': 0.9621}}

# %%
len(res)
# Out:
# 65

# %%
from decimal import Decimal

output=[]
for item in res:
  if(Decimal(res[item]['neg'])>0.5):
    output.append('Negative')
  elif(Decimal(res[item]['pos'])>0.5):
    output.append('Positive')
  elif(Decimal(res[item]['neu'])>0.5):
    output.append('Neutral')
  else:
    output.append('Neutral')

# %%
len(output)
# Out:
# 65

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 3  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 4  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 3   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 4   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
# 1                 NaN        NaN                NaN              4
# 2                 NaN        NaN                NaN              5
# 3                 NaN        NaN                NaN              5
# 4                 NaN        NaN                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
# 2  https://www.amazon.com/product-reviews/B00QWO9...
# 3  https://www.amazon.com/product-reviews/B00QWO9...
# 4  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...
# 3  https://www.barcodable.com/upc/841710106442,ht...
# 4  https://www.barcodable.com/upc/841710106442,ht...
#
# [5 rows x 24 columns]

# %%
df.to_csv('/content/sentiment_analysis.csv')
# Out:
#   File "C:\Users\shrey\AppData\Local\Temp\ipykernel_7500\2934218508.py", line 1
#     df.to_csv('C:\Users\shrey\Downloads\archive (2)\Book1.csv')
#                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df['Classification'].value_counts()
